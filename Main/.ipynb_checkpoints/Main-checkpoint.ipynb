# %% [markdown]
# ### Game Creation Prediction System

# %% [markdown]
# ##### Content Page

# %%
import mysql.connector as mysql #pip install mysql.connector 
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
import requests
import json
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from imblearn.over_sampling import SMOTE , ADASYN # for imbalanced data
from imblearn.combine import SMOTEENN 
from imblearn.pipeline import make_pipeline
import time

# %% [markdown]
# ### Main Question : How can game developers safely and accurately use user’s behaviour to predict the next big game?
#
# ##### To answer this question, we need to break it down into parts :
# ##### 1) Does friends playing the game affect whether someone will buy a game?
# ##### 2) Does Multiplayer games cost more than single player games?
# ##### 3) Are multiplayer games more popular than single player games?
# ##### 4) What is the most popular genre? (think we did this alrdy)
# ##### 5) Does age requirements affect game's popularity?
# ##### 6) Does common words in descripition affect game's popularity?
# ##### 7) Does having achievements in game affect playtime, rating , popularity?
# ##### 8) What is a user's most played genre and how likely are they to play other game genres?

# %% [markdown]
# ### Data Cleaning
#
# ##### Firstly , let us query our database for the list of user accounts, because this sql database has 100m our data, it would be too expensive to constantly querying it for data, so we shall export it to a csv

# %%
#Database Connection (dont run this again , too costly!!)
db_connection = mysql.connect(user="root", password="jajasauce", host="34.143.214.112", database="steam")
cur = db_connection.cursor()

cur.execute("SELECT steamid,personaname FROM Player_Summaries WHERE personastate != 0 LIMIT 100000;") # We shall only limit it to 100,000 because of the large dataset
myresult = cur.fetchall()
df = pd.DataFrame(myresult,columns=['steamid','personaname'])
df.to_csv('playerinfo.csv', index=False) #We exported it to a csv file

# %% [markdown]
# ##### Next, we have to query steam's API to get the list of games the users has played. This is because our dataset only has userID and not the list of games they played
# (https://developer.valvesoftware.com/wiki/Steam_Web_API)

# %%
# Using API 
API = "4141070D32E9CF793B1D9BC8A25C5950"

# %%
steam_data = pd.read_csv("SteamUserData/playerInfo.csv",nrows=20000) #We found out that 100,000 data is too much because each user could have thousands of games, and with just 20,000 users, there is already 500,000 data

#Getting list of User game library data
data1 = {'steamid':[],'gamesid':[],'playtime_forever':[]}
dfGames = pd.DataFrame(data1)

for x in steam_data['steamid']:
    response = requests.get("http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key="+API+"&steamid="+str(x)+"&format=json")
    reply = response.json(); 
    if(reply['response'] == {}):
        continue
    else:
        for y in reply['response']['games']: # save it to data frame instead
            new_row = {'steamid':str(x),'gamesid':y['appid'],'playtime_forever':y['playtime_forever']}
            dfGames = dfGames.append(new_row, ignore_index=True)
          
    
dfGames.to_csv('playerGames.csv', index=False)

# %% [markdown]
# ##### Now that we have the list of games the users played lets merge both data together with another dataset of game's infomation (../SteamUserData/App_ID_Info.cs)
# ##### This is so that we can get the infomation of the games they played and merge it using gameid

# %%
#Firstly lets get the list of players and the games they play
#Lets clean the data by removing games which is free because they have other ways of earning money (DLCs). If App types are not games, we want to remove it as well
User_Data = pd.read_csv("../SteamUserData/playerGames.csv")
App_Info = pd.read_csv("../SteamUserData/App_ID_Info.csv")

Merged = pd.merge(User_Data,App_Info[['gamesid','appType','price','rating','is_Multiplayer']],on=["gamesid"])

#Now lets drop those columns with prices = 0.00 and appType not equal to games
Merged = Merged.drop(Merged[(Merged.price == 0) | (Merged.appType != "game")].index)
#There is now 350k of data instead of 500k of data
#Let us futher merge the table with genres to do EDA
#genres = pd.read_csv("../SteamUserData/Game_Genres.csv")
#UserGame = pd.merge(Merged,genres,on=["gamesid"]) # Game has multiple genres

# %% [markdown]
# #### 1) Does friends playing the game affect whether someone will buy a game?
#
#
# #### First we must call API to check the list of friends a player has and whether they own that same game

# %%
#Get the list of friends for each user , this has to be done by calling APIs
#Using friend list , query whether they got the same game
counter = 0; #limited 100,000 API query a day
Merged = pd.read_csv("../steamdata/PlayerGames_Cleaned.csv")
for x in range(len(Merged['steamid'])):
    response = requests.get("https://api.steampowered.com/ISteamUser/GetFriendList/v0001/?key="+API+"&steamid="+str(Merged['steamid'][x])+"&relationship=friend")
    reply = response.json();
    if(reply == {}):
        continue
    else:
        friendHave = 0;
        for y in reply['friendslist']['friends']: # save it to data frame instead
            if(friendHave == 1):
                break;
            friendResponse = requests.get("http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key="+API+"&steamid="+str(y['steamid'])+"&format=json")
            friendReply = friendResponse.json();
            counter += 1;
            if(friendReply['response'] == {}):
                continue;
            else:
                if(int(friendReply['response']['game_count']) == 0):
                    continue;
                else:
                    for friendGame in friendReply['response']['games']:
                        if(friendGame['appid'] == Merged['gamesid'][x]):
                            friendHave = 1;
                            break;
                                         
    Merged['FriendHasGame'][x] = friendHave;
    Merged.to_csv('PlayerGames_Cleaned.csv', index=False) 

Merged.to_csv('PlayerGames_Cleaned.csv', index=False)

# %%
Merged = pd.read_csv("../SteamUserData/PlayerGames_Cleaned.csv")


Merged['FriendHasGame'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1) We can see that when a friend has the game, they might influence the user to buy and play the game as well
#
# #### Now let us analyze the 2nd question
# #### 2) Does Multiplayer games cost more than single player games?

# %%
cost = pd.read_csv("../SteamUserData/App_ID_Info.csv")
#We want to remove appType that are not games.

costCleaned = cost[cost['appType']=='game'] #Clean data to make it only games
costCleaned = costCleaned[cost['price'] > 0] # Remove games that cost $0 because they have other ways of earning money

#now that we have all the list of games, lets do some analysis on it
plt.figure(figsize=(10, 10))
sb.boxplot(data=costCleaned,y="is_Multiplayer",x="price" ,orient = "h")
# Out:
# <AxesSubplot:xlabel='price', ylabel='is_Multiplayer'>

# %% [markdown]
# Now let us remove the outliers so we can get a clearer picture

# %%
#Let us remove the outliers so we can get a clearer picture
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

cost1= remove_outlier(costCleaned, "price")
sb.boxplot(data=cost1,x="is_Multiplayer",y="price")
# Out:
# <AxesSubplot:xlabel='is_Multiplayer', ylabel='price'>

# %% [markdown]
# 2) We can see that those multiplayer games have a higher interqualite range and median than those non multiplayer games, which shows that multiplayer games, on average, tend to be on the pricer side than non-multiplaye. And therefore, affects the price of a game
#
# ### 3) Are multiplayer games more popular than single player games?
# To answer this question, we need merge with another dataset that shows average user play time on a game , and more info on that game

# %%
gameData = pd.read_csv("../SteamUserData/App_ID_Info.csv")
gamePopularity = pd.read_csv("../steamdata/steamdata_clean.csv")

gameData =  pd.merge(gameData,gamePopularity[['steam_appid','average_forever']],left_on=["gamesid"],right_on=["steam_appid"])
gameData = gameData.drop(gameData[(gameData.average_forever <= 0)].index) # remove data that cannot find average playtime
gameData
# Out:
#       gamesid                     appName appType  price         release_Date  \
# 0          10              Counter-Strike    game   9.99  2000-11-01 00:00:00
# 1          20       Team Fortress Classic    game   4.99  1999-04-01 00:00:00
# 2          30               Day of Defeat    game   4.99  2003-05-01 00:00:00
# 3          40          Deathmatch Classic    game   4.99  2001-06-01 00:00:00
# 4          50   Half-Life: Opposing Force    game   4.99  1999-11-01 00:00:00
# ...       ...                         ...     ...    ...                  ...
# 7549   466890                    Z.I.O.N.    game   4.99  2016-05-07 00:00:00
# 7550   466910           Worm.is: The Game    game   0.00  2016-05-04 00:00:00
# 7551   467000                   Insincere    game  39.99  2016-05-12 00:00:00
# 7553   467310  Rogue Port - Red Nightmare    game   0.00  2016-05-12 00:00:00
# 7555   467370                 Escape This    game   0.99  2016-05-04 00:00:00
#
#       rating  requiredAge  is_Multiplayer  steam_appid  average_forever
# 0         88            0               1           10            17612
# 1         -1            0               1           20              277
# 2         79            0               1           30              187
# 3         -1            0               1           40              258
# 4         -1            0               1           50              624
# ...      ...          ...             ...          ...              ...
# 7549      -1            0               0       466890              384
# 7550      -1            0               1       466910               68
# 7551      -1            0               0       467000              257
# 7553      -1            0               0       467310              295
# 7555      -1            0               0       467370              215
#
# [3366 rows x 10 columns]

# %% [markdown]
# Now lets look at the top performing games with the highest amount of user's playtime.

# %%
#Let us normalise the data to make it easier to read
df_max_scaled = gameData.copy()
df_max_scaled = df_max_scaled.nlargest(n=10,columns=["average_forever"])
#df_max_scaled
df_max_scaled["average_forever"] = df_max_scaled["average_forever"]  / df_max_scaled["average_forever"].abs().max()
    
df_max_scaled.plot.bar(x = 'appName', y = 'average_forever', color = 'skyblue', title = 'Top 10 Games by average play time')
# Out:
# <AxesSubplot:title={'center':'Top 10 Games by average play time'}, xlabel='appName'>

# %%
df_max_scaled['is_Multiplayer'].value_counts()
# Out:
# 1    6
# 0    4
# Name: is_Multiplayer, dtype: int64

# %% [markdown]
# We see that 6 out of 10 games in the top 10 games are multiplayer games, lets increase our datasize to get a clearer picture

# %%
df_max_scaled = gameData.copy()
df_max_scaled = df_max_scaled.nlargest(n=100,columns=["average_forever"])
df_max_scaled['is_Multiplayer'].value_counts()
df_max_scaled = gameData.copy()
df_max_scaled = df_max_scaled.nlargest(n=1000,columns=["average_forever"])
df_max_scaled['is_Multiplayer'].value_counts()
# Out:
# 0    603
# 1    397
# Name: is_Multiplayer, dtype: int64

# %% [markdown]
# 3. This is also quite true for a larger datasize. At the top 100 games and 1000 games based on all user's average play time, about 60% are multiplayer games and about 40% are single player games
# We concluded that there is a small higher percent of chance that popular games are multiplayer games based solely on highest average playtime.
#
# Now let us continue and take a look at the average whether there are more multiplayer games with higher average playtime or single player games with higher average playtime.

# %%
sb.boxplot(data=gameData,x="is_Multiplayer",y="average_forever")
# Out:
# <AxesSubplot:xlabel='is_Multiplayer', ylabel='average_forever'>

# %%
#Lets remove out outiers
gameData= remove_outlier(gameData, "average_forever")
sb.boxplot(data=gameData,x="is_Multiplayer",y="average_forever")
# Out:
# <AxesSubplot:xlabel='is_Multiplayer', ylabel='average_forever'>

# %% [markdown]
# 3) We see that on average, there is not much difference between user's play time when the game is multiplayer or single player.
#
# So, to futher find a "popularity of a game", we need to see how many people bought the game. Now, lets look at how many people bought the game and whether multiplayer games has more people buying it or not.

# %%
gameData = pd.read_csv("../SteamUserData/App_ID_Info.csv")
gamePopularity = pd.read_csv("../steamdata/steamdata_clean.csv")

gameData =  pd.merge(gameData,gamePopularity[['steam_appid','average_forever','owners']],left_on=["gamesid"],right_on=["steam_appid"])
gameData = gameData.drop(gameData[(gameData.average_forever <= 0)].index) # remove data that cannot find average playtime
gameDataMultiplayer1 = gameData.drop(gameData[(gameData.is_Multiplayer == 0)].index)


#When game is multiplayer
gameDataMultiplayer1['owners'].value_counts().plot(kind='barh')
gameDataMultiplayer1['owners'].value_counts()

#We shall map this caetegorical to a numercial data so that we can get a rough estimate of the number of players
gameDataMultiplayer1['ownersNumerical'] = gameDataMultiplayer1['owners'].map({
    "200,000 .. 500,000": 250000,
    "100,000 .. 200,000": 150000,
    "500,000 .. 1,000,000": 750000,
    "1,000,000 .. 2,000,000": 150000,
    "50,000 .. 100,000": 75000,
    "2,000,000 .. 5,000,000": 3500000,
    "20,000 .. 50,000": 35000,
    "0 .. 20,000": 10000,
    "5,000,000 .. 10,000,000": 7500000,
    "10,000,000 .. 20,000,000": 1500000,
    "20,000,000 .. 50,000,000": 35000000,
    "100,000,000 .. 200,000,000": 150000000,
    "50,000,000 .. 100,000,000": 75000000,
})

# %%
gameDataMultiplayer0 = gameData.drop(gameData[(gameData.is_Multiplayer == 1)].index)


#When game is not multiplayer
gameDataMultiplayer0['owners'].value_counts().plot(kind='barh')
gameDataMultiplayer0['owners'].value_counts()
#We shall map this caetegorical to a numercial data so that we can get a rough estimate of the number of players
gameDataMultiplayer0['ownersNumerical'] = gameDataMultiplayer0['owners'].map({
    "200,000 .. 500,000": 250000,
    "100,000 .. 200,000": 150000,
    "500,000 .. 1,000,000": 750000,
    "1,000,000 .. 2,000,000": 150000,
    "50,000 .. 100,000": 75000,
    "2,000,000 .. 5,000,000": 3500000,
    "20,000 .. 50,000": 35000,
    "0 .. 20,000": 10000,
    "5,000,000 .. 10,000,000": 7500000,
    "10,000,000 .. 20,000,000": 1500000,
    "20,000,000 .. 50,000,000": 35000000,
    "100,000,000 .. 200,000,000": 150000000,
    "50,000,000 .. 100,000,000": 75000000,
})

# %%
#Sum of the estimated total number of users buying multiplayer games
gameDataMultiplayer1['ownersNumerical'].sum()
# Out:
# 1080420000

# %%
#Sum of the estimated total number of users buying single player games
gameDataMultiplayer0['ownersNumerical'].sum()
# Out:
# 756235000

# %% [markdown]
# 4. Based on our estimates, we see that more users buy multiplayer games as compared to single player games. However, if based on users play time, both multiplayer and single player does not have much difference(one 60% the other 40%)

# %% [markdown]
# ### 5) Does age requirements affect game's popularity?
#
# First we must see how many people own age restricted games and make a comparison between those non age restricted games

# %%
gameData = pd.read_csv("../SteamUserData/App_ID_Info.csv")
gamePopularity = pd.read_csv("../steamdata/steamdata_clean.csv")

gameData =  pd.merge(gameData,gamePopularity[['steam_appid','average_forever','owners']],left_on=["gamesid"],right_on=["steam_appid"])
gameData['YesNoAge'] = ""
counter = 0
for x in gameData['requiredAge']:
    if(x > 0):
        gameData['YesNoAge'][counter] = "Yes"
    else:
        gameData['YesNoAge'][counter] = "No"
    counter+=1

# %%
gameData2  = gameData.drop(gameData[(gameData.rating == -1)].index)
sb.boxplot(data=gameData2,x="YesNoAge",y="rating")
# Out:
# <AxesSubplot:xlabel='YesNoAge', ylabel='rating'>

# %% [markdown]
# Not much difference of age resticted game's rating and no age restricted game rating.

# %%
#sb.boxplot(data=gameData,x="YesNoAge",y="rating")

gameData['ownersNumerical'] = gameData['owners'].map({
    "200,000 .. 500,000": 250000,
    "100,000 .. 200,000": 150000,
    "500,000 .. 1,000,000": 750000,
    "1,000,000 .. 2,000,000": 150000,
    "50,000 .. 100,000": 75000,
    "2,000,000 .. 5,000,000": 3500000,
    "20,000 .. 50,000": 35000,
    "0 .. 20,000": 10000,
    "5,000,000 .. 10,000,000": 7500000,
    "10,000,000 .. 20,000,000": 1500000,
    "20,000,000 .. 50,000,000": 35000000,
    "100,000,000 .. 200,000,000": 150000000,
    "50,000,000 .. 100,000,000": 75000000,
})

def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

gameData= remove_outlier(gameData, "ownersNumerical")


sb.boxplot(data=gameData,x="YesNoAge",y="ownersNumerical")
# Out:
# <AxesSubplot:xlabel='YesNoAge', ylabel='ownersNumerical'>

# %% [markdown]
# 5) We see that on average, there is a higher chance of age restricted games being more popular , as there are more people buying such games

# %% [markdown]
# #### Does age restriction affect prices?

# %%
gameData = pd.read_csv("../SteamUserData/AppDataMerged.csv")

counter = 0
gameData['YesNoAge'] = ""
for x in gameData['requiredAge']:
    if(x > 0):
        gameData['YesNoAge'][counter] = "Yes"
    else:
        gameData['YesNoAge'][counter] = "No"
    counter+=1
sb.boxplot(data=gameData2,x="YesNoAge",y="price")
# Out:
# <AxesSubplot:xlabel='YesNoAge', ylabel='price'>

# %% [markdown]
# We see that on average, age restricted games does affect prices

# %% [markdown]
# ### 6) Does common words in game's descripition affect game's popularity?

# %%
data = pd.read_csv("../steamdata/steamdata_clean.csv")
data["short_description"] = data["short_description"].fillna("")
from wordcloud import WordCloud, STOPWORDS

name_corpus = ' '.join(data["name"])
name_wordcloud = WordCloud(stopwords = STOPWORDS, background_color = 'white', height = 1000, width = 2000).generate(name_corpus)
plt.figure(figsize=(16,8))
plt.imshow(name_wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\leewe\Desktop\1015\Main\Main.ipynb Cell 42' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000043?line=0'>1</a> data = pd.read_csv("../steamdata/steamdata_clean.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000043?line=1'>2</a> data["short_description"] = data["short_description"].fillna("")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000043?line=2'>3</a> from wordcloud import WordCloud, STOPWORDS
#       <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000043?line=4'>5</a> name_corpus = ' '.join(data["name"])
#       <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000043?line=5'>6</a> name_wordcloud = WordCloud(stopwords = STOPWORDS, background_color = 'white', height = 1000, width = 2000).generate(name_corpus)
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ### 7) Does having achievements in game affect playtime, rating , popularity?

# %%
gameData = pd.read_csv("../SteamUserData/App_ID_Info.csv")
gamePopularity = pd.read_csv("../steamdata/steamdata_clean.csv")
gameAchievement = pd.read_csv("../SteamUserData/Achievement_Percentages.csv")



gameData =  pd.merge(gameData,gamePopularity[['steam_appid','average_forever','owners']],left_on=["gamesid"],right_on=["steam_appid"])
counter = 0
gameData['achievement'] = ""
for x in gameData['gamesid']:
    if x in gameAchievement['gamesid']:
        gameData['achievement'][counter] = "Yes"
    else:
        gameData['achievement'][counter]  = "No"
    counter +=1
    
gameData['ownersNumerical'] = gameData['owners'].map({
    "200,000 .. 500,000": 250000,
    "100,000 .. 200,000": 150000,
    "500,000 .. 1,000,000": 750000,
    "1,000,000 .. 2,000,000": 150000,
    "50,000 .. 100,000": 75000,
    "2,000,000 .. 5,000,000": 3500000,
    "20,000 .. 50,000": 35000,
    "0 .. 20,000": 10000,
    "5,000,000 .. 10,000,000": 7500000,
    "10,000,000 .. 20,000,000": 1500000,
    "20,000,000 .. 50,000,000": 35000000,
    "100,000,000 .. 200,000,000": 150000000,
    "50,000,000 .. 100,000,000": 75000000,
})


gameData.to_csv('../SteamUserData/AppDataMerged.csv', index=False)

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

gameData= remove_outlier(gameData, "ownersNumerical")
sb.boxplot(data=gameData,x="achievement",y="ownersNumerical")
# Out:
# <AxesSubplot:xlabel='achievement', ylabel='ownersNumerical'>

# %% [markdown]
# We see that having achievements does affect whether people buy games
#
# Does Achievements Affect cost?

# %%
gameData = pd.read_csv("../SteamUserData/AppDataMerged.csv")
gameData= remove_outlier(gameData, "price")
sb.boxplot(data=gameData,x="achievement",y="price")
# Out:
# <AxesSubplot:xlabel='achievement', ylabel='price'>

# %% [markdown]
# ##### Achievements does not really affect prices

# %% [markdown]
# Things that might affect cost prediction:
# 1) Multiplayer games cost more than single player games
# 2) multiplayer games cost most on average
# 3) Age Restricted Games
#
# Things that affect whether a user will buy a game:
# 1) When friends has the game
# 2) When it is a multiplayer game
# 3) Achievements
# 4) Age restricted games

# %% [markdown]
# #### Now lets look at the Pearson correlation Coefficient between those things affected

# %%
from dython.nominal import associations
from dython.nominal import identify_nominal_columns


gameData = pd.read_csv("../steamdata/steamdata_clean.csv")
addRequiredAge = pd.read_csv("../SteamUserData/AppDataMerged.csv")
gameData =  pd.merge(gameData,addRequiredAge[['gamesid','requiredAge']],right_on=["gamesid"],left_on=["steam_appid"])
counter =0
for x in gameData['requiredAge']:
    if(int(x) >0):
        gameData['requiredAge'][counter] = 1;
    else:
        gameData['requiredAge'][counter] = 0;
    counter += 1;

def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

gameData= remove_outlier(gameData, "initialprice")
#categorical_features=identify_nominal_columns(gameData)
complete_correlation= associations(gameData, filename= 'complete_correlation.png', figsize=(10,10))
df_complete_corr=complete_correlation['corr']
df_complete_corr.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style type="text/css">
# #T_a8428_row0_col0, #T_a8428_row0_col1, #T_a8428_row0_col2, #T_a8428_row0_col3, #T_a8428_row0_col5, #T_a8428_row0_col7, #T_a8428_row0_col8, #T_a8428_row0_col14, #T_a8428_row0_col15, #T_a8428_row0_col16, #T_a8428_row0_col19, #T_a8428_row0_col20, #T_a8428_row0_col21, #T_a8428_row0_col22, #T_a8428_row1_col0, #T_a8428_row1_col1, #T_a8428_row1_col4, #T_a8428_row1_col21, #T_a8428_row2_col0, #T_a8428_row2_col2, #T_a8428_row2_col4, #T_a8428_row3_col0, #T_a8428_row3_col3, #T_a8428_row3_col4, #T_a8428_row4_col1, #T_a8428_row4_col2, #T_a8428_row4_col3, #T_a8428_row4_col4, #T_a8428_row4_col5, #T_a8428_row4_col7, #T_a8428_row4_col8, #T_a8428_row4_col14, #T_a8428_row4_col15, #T_a8428_row4_col16, #T_a8428_row4_col19, #T_a8428_row4_col20, #T_a8428_row4_col21, #T_a8428_row4_col22, #T_a8428_row5_col0, #T_a8428_row5_col4, #T_a8428_row5_col5, #T_a8428_row6_col6, #T_a8428_row7_col0, #T_a8428_row7_col4, #T_a8428_row7_col7, #T_a8428_row8_col0, #T_a8428_row8_col4, #T_a8428_row8_col8, #T_a8428_row9_col9, #T_a8428_row10_col10, #T_a8428_row11_col11, #T_a8428_row12_col12, #T_a8428_row13_col13, #T_a8428_row14_col0, #T_a8428_row14_col4, #T_a8428_row14_col14, #T_a8428_row14_col18, #T_a8428_row15_col0, #T_a8428_row15_col4, #T_a8428_row15_col15, #T_a8428_row15_col18, #T_a8428_row16_col0, #T_a8428_row16_col4, #T_a8428_row16_col16, #T_a8428_row17_col17, #T_a8428_row18_col14, #T_a8428_row18_col15, #T_a8428_row18_col18, #T_a8428_row19_col0, #T_a8428_row19_col4, #T_a8428_row19_col19, #T_a8428_row20_col0, #T_a8428_row20_col4, #T_a8428_row20_col20, #T_a8428_row21_col0, #T_a8428_row21_col1, #T_a8428_row21_col4, #T_a8428_row21_col21, #T_a8428_row22_col0, #T_a8428_row22_col4, #T_a8428_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a8428_row0_col4, #T_a8428_row0_col6, #T_a8428_row0_col18, #T_a8428_row4_col0, #T_a8428_row5_col14, #T_a8428_row5_col15, #T_a8428_row6_col0, #T_a8428_row6_col9, #T_a8428_row6_col17, #T_a8428_row9_col6, #T_a8428_row9_col11, #T_a8428_row9_col12, #T_a8428_row11_col9, #T_a8428_row11_col13, #T_a8428_row12_col9, #T_a8428_row12_col13, #T_a8428_row12_col17, #T_a8428_row12_col18, #T_a8428_row13_col11, #T_a8428_row13_col12, #T_a8428_row14_col5, #T_a8428_row15_col5, #T_a8428_row17_col6, #T_a8428_row17_col12, #T_a8428_row18_col0, #T_a8428_row18_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_a8428_row0_col9, #T_a8428_row3_col8, #T_a8428_row8_col3, #T_a8428_row9_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_a8428_row0_col10, #T_a8428_row4_col10, #T_a8428_row10_col0, #T_a8428_row10_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_a8428_row0_col11, #T_a8428_row11_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a8428_row0_col12, #T_a8428_row12_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a8428_row0_col13, #T_a8428_row8_col15, #T_a8428_row8_col22, #T_a8428_row13_col0, #T_a8428_row15_col8, #T_a8428_row15_col20, #T_a8428_row20_col15, #T_a8428_row22_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_a8428_row0_col17, #T_a8428_row17_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a8428_row1_col2, #T_a8428_row2_col1, #T_a8428_row2_col21, #T_a8428_row21_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_a8428_row1_col3, #T_a8428_row3_col1, #T_a8428_row3_col21, #T_a8428_row4_col13, #T_a8428_row5_col8, #T_a8428_row6_col13, #T_a8428_row8_col5, #T_a8428_row13_col4, #T_a8428_row13_col6, #T_a8428_row15_col19, #T_a8428_row19_col15, #T_a8428_row21_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col5, #T_a8428_row5_col1, #T_a8428_row5_col21, #T_a8428_row21_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col6, #T_a8428_row2_col20, #T_a8428_row6_col1, #T_a8428_row6_col21, #T_a8428_row20_col2, #T_a8428_row21_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a8428_row1_col7, #T_a8428_row7_col1, #T_a8428_row7_col21, #T_a8428_row21_col7 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col8, #T_a8428_row5_col22, #T_a8428_row8_col1, #T_a8428_row8_col21, #T_a8428_row15_col22, #T_a8428_row21_col8, #T_a8428_row22_col5, #T_a8428_row22_col15 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col9, #T_a8428_row8_col18, #T_a8428_row9_col1, #T_a8428_row9_col21, #T_a8428_row18_col8, #T_a8428_row18_col22, #T_a8428_row21_col9, #T_a8428_row22_col18 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col10, #T_a8428_row6_col12, #T_a8428_row7_col17, #T_a8428_row10_col1, #T_a8428_row10_col21, #T_a8428_row12_col6, #T_a8428_row17_col7, #T_a8428_row21_col10 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a8428_row1_col11, #T_a8428_row11_col1, #T_a8428_row11_col21, #T_a8428_row18_col19, #T_a8428_row19_col18, #T_a8428_row21_col11 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col12, #T_a8428_row1_col18, #T_a8428_row5_col18, #T_a8428_row7_col11, #T_a8428_row11_col7, #T_a8428_row11_col22, #T_a8428_row12_col1, #T_a8428_row12_col21, #T_a8428_row18_col1, #T_a8428_row18_col5, #T_a8428_row18_col21, #T_a8428_row21_col12, #T_a8428_row21_col18, #T_a8428_row22_col11 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col13, #T_a8428_row13_col1, #T_a8428_row13_col21, #T_a8428_row21_col13 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a8428_row1_col14, #T_a8428_row14_col1, #T_a8428_row14_col21, #T_a8428_row21_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col15, #T_a8428_row2_col15, #T_a8428_row15_col1, #T_a8428_row15_col2, #T_a8428_row15_col21, #T_a8428_row21_col15 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col16, #T_a8428_row16_col1, #T_a8428_row16_col21, #T_a8428_row21_col16 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col17, #T_a8428_row9_col16, #T_a8428_row16_col9, #T_a8428_row17_col1, #T_a8428_row17_col21, #T_a8428_row21_col17 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_a8428_row1_col19, #T_a8428_row15_col16, #T_a8428_row16_col15, #T_a8428_row19_col1, #T_a8428_row19_col20, #T_a8428_row19_col21, #T_a8428_row20_col19, #T_a8428_row21_col19 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col20, #T_a8428_row20_col1, #T_a8428_row20_col21, #T_a8428_row21_col20 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a8428_row1_col22, #T_a8428_row21_col22, #T_a8428_row22_col1, #T_a8428_row22_col21 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a8428_row2_col3, #T_a8428_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a8428_row2_col5, #T_a8428_row5_col2, #T_a8428_row7_col14, #T_a8428_row7_col15, #T_a8428_row14_col7, #T_a8428_row14_col16, #T_a8428_row15_col7, #T_a8428_row16_col14, #T_a8428_row19_col22, #T_a8428_row22_col19 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a8428_row2_col6, #T_a8428_row6_col2, #T_a8428_row8_col20, #T_a8428_row11_col18, #T_a8428_row18_col11, #T_a8428_row20_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a8428_row2_col7, #T_a8428_row3_col20, #T_a8428_row6_col20, #T_a8428_row7_col2, #T_a8428_row20_col3, #T_a8428_row20_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_a8428_row2_col8, #T_a8428_row8_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a8428_row2_col9, #T_a8428_row9_col2 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a8428_row2_col10, #T_a8428_row10_col2, #T_a8428_row13_col18, #T_a8428_row18_col13 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_a8428_row2_col11, #T_a8428_row8_col11, #T_a8428_row11_col2, #T_a8428_row11_col8, #T_a8428_row11_col19, #T_a8428_row19_col11 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_a8428_row2_col12, #T_a8428_row12_col2, #T_a8428_row12_col16, #T_a8428_row16_col12 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_a8428_row2_col13, #T_a8428_row6_col16, #T_a8428_row13_col2, #T_a8428_row16_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_a8428_row2_col14, #T_a8428_row2_col22, #T_a8428_row14_col2, #T_a8428_row22_col2 {
#   background-colo

# %% [markdown]
# We see that developer and publisher has a strong linear correlation between initialprice.
# Developer and publisher also has a strong linear correltation between average_forever , which means the developer and publisher affects popularity and price of a game.
#
# We see that genre has a medium correlation on initialprice , average hours played and owners owning the game.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(gameData, alpha=0.2, figsize=(15,15), diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='steam_appid', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='dlc', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='demos', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='movies', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='achievements', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='rating', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='steam_appid'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='steam_appid'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='dlc', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='demos', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='movies', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='achievements', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='rating', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='controller_support'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='controller_support'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='dlc'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='dlc'>,
#         <AxesSubplot:xlabel='dlc', ylabel='dlc'>,
#         <AxesSubplot:xlabel='demos', ylabel='dlc'>,
#         <AxesSubplot:xlabel='movies', ylabel='dlc'>,
#         <AxesSubplot:xlabel='achievements', ylabel='dlc'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='dlc'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='dlc'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='dlc'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='dlc'>,
#         <AxesSubplot:xlabel='rating', ylabel='dlc'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='dlc'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='dlc'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='demos'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='demos'>,
#         <AxesSubplot:xlabel='dlc', ylabel='demos'>,
#         <AxesSubplot:xlabel='demos', ylabel='demos'>,
#         <AxesSubplot:xlabel='movies', ylabel='demos'>,
#         <AxesSubplot:xlabel='achievements', ylabel='demos'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='demos'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='demos'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='demos'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='demos'>,
#         <AxesSubplot:xlabel='rating', ylabel='demos'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='demos'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='demos'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='movies'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='movies'>,
#         <AxesSubplot:xlabel='dlc', ylabel='movies'>,
#         <AxesSubplot:xlabel='demos', ylabel='movies'>,
#         <AxesSubplot:xlabel='movies', ylabel='movies'>,
#         <AxesSubplot:xlabel='achievements', ylabel='movies'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='movies'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='movies'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='movies'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='movies'>,
#         <AxesSubplot:xlabel='rating', ylabel='movies'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='movies'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='movies'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='achievements'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='achievements'>,
#         <AxesSubplot:xlabel='dlc', ylabel='achievements'>,
#         <AxesSubplot:xlabel='demos', ylabel='achievements'>,
#         <AxesSubplot:xlabel='movies', ylabel='achievements'>,
#         <AxesSubplot:xlabel='achievements', ylabel='achievements'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='achievements'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='achievements'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='achievements'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='achievements'>,
#         <AxesSubplot:xlabel='rating', ylabel='achievements'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='achievements'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='achievements'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='dlc', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='demos', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='movies', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='achievements', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='rating', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='average_forever'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='average_forever'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='dlc', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='demos', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='movies', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='achievements', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='rating', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='median_forever'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='median_forever'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='dlc', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='demos', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='movies', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='achievements', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='rating', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='initialprice'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='initialprice'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='dlc', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='demos', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='movies', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='achievements', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='rating', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='is_multiplayer'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='is_multiplayer'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='rating'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='rating'>,
#         <AxesSubplot:xlabel='dlc', ylabel='rating'>,
#         <AxesSubplot:xlabel='demos', ylabel='rating'>,
#         <AxesSubplot:xlabel='movies', ylabel='rating'>,
#         <AxesSubplot:xlabel='achievements', ylabel='rating'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='rating'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='rating'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='rating'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='rating'>,
#         <AxesSubplot:xlabel='rating', ylabel='rating'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='rating'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='rating'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='dlc', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='demos', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='movies', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='achievements', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='rating', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='gamesid'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='gamesid'>],
#        [<AxesSubplot:xlabel='steam_appid', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='controller_support', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='dlc', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='demos', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='movies', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='achievements', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='average_forever', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='median_forever', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='initialprice', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='is_multiplayer', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='rating', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='gamesid', ylabel='requiredAge'>,
#         <AxesSubplot:xlabel='requiredAge', ylabel='requiredAge'>]],
#       dtype=object)

# %%
#Seperate each genre to get better correlation
"""
genreCorr = gameData[['initialprice','genres']]
counter = 0
genreList = [];
maxSize = len(genreCorr['genres'])
for x in genreCorr['genres']:
    if(counter >= maxSize):
        break
    if ";" in x:
        genreList = x.split(";")
        for y in genreList:
            new_row = pd.DataFrame({'initialprice' : [genreCorr['initialprice'].iloc[counter]],'genres':[y]})
            genreCorr = genreCorr.append(new_row, ignore_index=True)
    
    counter += 1;

counter = 0;
for x in genreCorr['genres']:
    if ";" in x:
        genreCorr = genreCorr.drop([genreCorr.index[counter]])
    counter += 1
"""

# %%
#complete_correlation= associations(genreCorr,figsize=(10,10))
#df_complete_corr=complete_correlation['corr']
#df_complete_corr.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)

# %%
gamedata2 = pd.read_csv("../SteamUserData/AppDataMerged.csv")
counter =0
for x in gamedata2['requiredAge']:
    if(int(x) >0):
        gamedata2['requiredAge'][counter] = 1;
    else:
        gamedata2['requiredAge'][counter] = 0;
    counter += 1;

initialprice = gamedata2[['price']]
age = gamedata2[['requiredAge']]

X_train, X_test, y_train, y_test = train_test_split(initialprice,age , test_size = 0.20) # 20% into test set , 80 into training set

#Balance the dataset because of imbalance-issues
smote = SMOTE(sampling_strategy = 1 ,k_neighbors = 3, random_state=1) 
X_train, y_train = ADASYN().fit_resample(X_train, y_train)

dectree2 = DecisionTreeClassifier(max_depth= 6)
dectree2.fit(X_train, y_train)
f = plt.figure(figsize=(30,30))
plot_tree(dectree2, filled=True, rounded=True, 
          feature_names=["Price"], 
          class_names=["No ageRestrictions","Yes ageRestrictions"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\leewe\Desktop\1015\Main\Main.ipynb Cell 60' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000059?line=14'>15</a> #Balance the dataset because of imbalance-issues
#      <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000059?line=15'>16</a> smote = SMOTE(sampling_strategy = 1 ,k_neighbors = 3, random_state=1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000059?line=16'>17</a> X_train, y_train = ADASYN().fit_resample(X_train, y_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000059?line=18'>19</a> dectree2 = DecisionTreeClassifier(max_depth= 6)
#      <a href='vscode-notebook-cell:/c%3A/Users/leewe/Desktop/1015/Main/Main.ipynb#ch0000059?line=19'>20</a> dectree2.fit(X_train, y_train)
#
# NameError: name 'ADASYN' is not defined

# %% [markdown]
# We see that those with no age restrictions cost lesser

# %%
y_test_pred = dectree2.predict(X_test)
y_train_pred = dectree2.predict(X_train)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree2.score(X_train, y_train))
cnf_matrix3 = confusion_matrix(y_train, y_train_pred)
TPR = cnf_matrix3[1][1]/(cnf_matrix3[1][1] + cnf_matrix3[1][0])
FPR = cnf_matrix3[0][1]/(cnf_matrix3[0][1] + cnf_matrix3[0][0])
print("True Positive Rate \t\t:", TPR)
print("True Negative Rate \t\t:", 1-FPR)
print()
# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree2.score(X_test, y_test))
cnf_matrix4 = confusion_matrix(y_test, y_test_pred)
TPR = cnf_matrix4[1][1]/(cnf_matrix4[1][1] + cnf_matrix4[1][0])
FPR = cnf_matrix4[0][1]/(cnf_matrix4[0][1] + cnf_matrix4[0][0])
print("True Positive Rate \t\t:", TPR)
print("True Negative Rate \t\t:", 1-FPR)


# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.953853787628184
# True Positive Rate 		: 0.0625
# True Negative Rate 		: 0.9984369572768322
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9517195767195767
# True Positive Rate 		: 0.0547945205479452
# True Negative Rate 		: 0.9972202918693537
# <AxesSubplot:>

# %% [markdown]
# We see that there is a high classification accuracy and a high prediction rate for true negative

# %%
gamedata2 = pd.read_csv("../SteamUserData/AppDataMerged.csv")
initialprice = gamedata2[['price']]
age = gamedata2[['is_Multiplayer']]

X_train, X_test, y_train, y_test = train_test_split(initialprice,age , test_size = 0.20) # 20% into test set , 80 into training set
dectree2 = DecisionTreeClassifier(max_depth= 6)
dectree2.fit(X_train, y_train)
f = plt.figure(figsize=(50,50))
plot_tree(dectree2, filled=True, rounded=True, 
          feature_names=["Price"], 
          class_names=["is_Not_multiplayer","is_multiplayer"])
# Out:
# [Text(0.4505208333333333, 0.9444444444444444, 'Price <= 14.97\ngini = 0.369\nsamples = 6046\nvalue = [4571, 1475]\nclass = is_Not_multiplayer'),
#  Text(0.184375, 0.8333333333333334, 'Price <= 0.84\ngini = 0.325\nsamples = 4691\nvalue = [3733, 958]\nclass = is_Not_multiplayer'),
#  Text(0.10416666666666667, 0.7222222222222222, 'Price <= 0.345\ngini = 0.492\nsamples = 505\nvalue = [285, 220]\nclass = is_Not_multiplayer'),
#  Text(0.0875, 0.6111111111111112, 'gini = 0.491\nsamples = 504\nvalue = [285, 219]\nclass = is_Not_multiplayer'),
#  Text(0.12083333333333333, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.26458333333333334, 0.7222222222222222, 'Price <= 7.24\ngini = 0.29\nsamples = 4186\nvalue = [3448, 738]\nclass = is_Not_multiplayer'),
#  Text(0.15416666666666667, 0.6111111111111112, 'Price <= 4.74\ngini = 0.237\nsamples = 2341\nvalue = [2020, 321]\nclass = is_Not_multiplayer'),
#  Text(0.09166666666666666, 0.5, 'Price <= 1.43\ngini = 0.188\nsamples = 876\nvalue = [784, 92]\nclass = is_Not_multiplayer'),
#  Text(0.075, 0.3888888888888889, 'gini = 0.237\nsamples = 124\nvalue = [107, 17]\nclass = is_Not_multiplayer'),
#  Text(0.10833333333333334, 0.3888888888888889, 'Price <= 2.995\ngini = 0.18\nsamples = 752\nvalue = [677, 75]\nclass = is_Not_multiplayer'),
#  Text(0.06666666666666667, 0.2777777777777778, 'Price <= 2.24\ngini = 0.19\nsamples = 507\nvalue = [453, 54]\nclass = is_Not_multiplayer'),
#  Text(0.03333333333333333, 0.16666666666666666, 'Price <= 1.93\ngini = 0.178\nsamples = 212\nvalue = [191, 21]\nclass = is_Not_multiplayer'),
#  Text(0.016666666666666666, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.05, 0.05555555555555555, 'gini = 0.179\nsamples = 211\nvalue = [190, 21]\nclass = is_Not_multiplayer'),
#  Text(0.1, 0.16666666666666666, 'Price <= 2.74\ngini = 0.199\nsamples = 295\nvalue = [262, 33]\nclass = is_Not_multiplayer'),
#  Text(0.08333333333333333, 0.05555555555555555, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = is_multiplayer'),
#  Text(0.11666666666666667, 0.05555555555555555, 'gini = 0.189\nsamples = 293\nvalue = [262, 31]\nclass = is_Not_multiplayer'),
#  Text(0.15, 0.2777777777777778, 'Price <= 3.74\ngini = 0.157\nsamples = 245\nvalue = [224, 21]\nclass = is_Not_multiplayer'),
#  Text(0.13333333333333333, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = is_Not_multiplayer'),
#  Text(0.16666666666666666, 0.16666666666666666, 'Price <= 4.24\ngini = 0.158\nsamples = 243\nvalue = [222, 21]\nclass = is_Not_multiplayer'),
#  Text(0.15, 0.05555555555555555, 'gini = 0.158\nsamples = 242\nvalue = [221, 21]\nclass = is_Not_multiplayer'),
#  Text(0.18333333333333332, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.21666666666666667, 0.5, 'Price <= 4.995\ngini = 0.264\nsamples = 1465\nvalue = [1236, 229]\nclass = is_Not_multiplayer'),
#  Text(0.2, 0.3888888888888889, 'gini = 0.281\nsamples = 905\nvalue = [752, 153]\nclass = is_Not_multiplayer'),
#  Text(0.23333333333333334, 0.3888888888888889, 'Price <= 5.82\ngini = 0.235\nsamples = 560\nvalue = [484, 76]\nclass = is_Not_multiplayer'),
#  Text(0.21666666666666667, 0.2777777777777778, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = is_Not_multiplayer'),
#  Text(0.25, 0.2777777777777778, 'Price <= 6.74\ngini = 0.235\nsamples = 558\nvalue = [482, 76]\nclass = is_Not_multiplayer'),
#  Text(0.23333333333333334, 0.16666666666666666, 'Price <= 6.24\ngini = 0.244\nsamples = 225\nvalue = [193, 32]\nclass = is_Not_multiplayer'),
#  Text(0.21666666666666667, 0.05555555555555555, 'gini = 0.238\nsamples = 224\nvalue = [193, 31]\nclass = is_Not_multiplayer'),
#  Text(0.25, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.26666666666666666, 0.16666666666666666, 'gini = 0.229\nsamples = 333\nvalue = [289, 44]\nclass = is_Not_multiplayer'),
#  Text(0.375, 0.6111111111111112, 'Price <= 9.49\ngini = 0.35\nsamples = 1845\nvalue = [1428, 417]\nclass = is_Not_multiplayer'),
#  Text(0.31666666666666665, 0.5, 'Price <= 7.74\ngini = 0.308\nsamples = 326\nvalue = [264, 62]\nclass = is_Not_multiplayer'),
#  Text(0.3, 0.3888888888888889, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = is_Not_multiplayer'),
#  Text(0.3333333333333333, 0.3888888888888889, 'Price <= 8.985\ngini = 0.306\nsamples = 324\nvalue = [263, 61]\nclass = is_Not_multiplayer'),
#  Text(0.31666666666666665, 0.2777777777777778, 'Price <= 8.485\ngini = 0.302\nsamples = 243\nvalue = [198, 45]\nclass = is_Not_multiplayer'),
#  Text(0.3, 0.16666666666666666, 'gini = 0.303\nsamples = 242\nvalue = [197, 45]\nclass = is_Not_multiplayer'),
#  Text(0.3333333333333333, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.35, 0.2777777777777778, 'gini = 0.317\nsamples = 81\nvalue = [65, 16]\nclass = is_Not_multiplayer'),
#  Text(0.43333333333333335, 0.5, 'Price <= 13.18\ngini = 0.358\nsamples = 1519\nvalue = [1164, 355]\nclass = is_Not_multiplayer'),
#  Text(0.4, 0.3888888888888889, 'Price <= 12.49\ngini = 0.359\nsamples = 1501\nvalue = [1149, 352]\nclass = is_Not_multiplayer'),
#  Text(0.38333333333333336, 0.2777777777777778, 'Price <= 10.49\ngini = 0.358\nsamples = 1389\nvalue = [1064, 325]\nclass = is_Not_multiplayer'),
#  Text(0.36666666666666664, 0.16666666666666666, 'gini = 0.36\nsamples = 1314\nvalue = [1005, 309]\nclass = is_Not_multiplayer'),
#  Text(0.4, 0.16666666666666666, 'Price <= 11.49\ngini = 0.336\nsamples = 75\nvalue = [59, 16]\nclass = is_Not_multiplayer'),
#  Text(0.38333333333333336, 0.05555555555555555, 'gini = 0.32\nsamples = 15\nvalue = [12, 3]\nclass = is_Not_multiplayer'),
#  Text(0.4166666666666667, 0.05555555555555555, 'gini = 0.339\nsamples = 60\nvalue = [47, 13]\nclass = is_Not_multiplayer'),
#  Text(0.4166666666666667, 0.2777777777777778, 'gini = 0.366\nsamples = 112\nvalue = [85, 27]\nclass = is_Not_multiplayer'),
#  Text(0.4666666666666667, 0.3888888888888889, 'Price <= 13.68\ngini = 0.278\nsamples = 18\nvalue = [15, 3]\nclass = is_Not_multiplayer'),
#  Text(0.45, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.48333333333333334, 0.2777777777777778, 'Price <= 14.47\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = is_Not_multiplayer'),
#  Text(0.4666666666666667, 0.16666666666666666, 'gini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = is_Not_multiplayer'),
#  Text(0.5, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.7166666666666667, 0.8333333333333334, 'Price <= 22.16\ngini = 0.472\nsamples = 1355\nvalue = [838, 517]\nclass = is_Not_multiplayer'),
#  Text(0.6083333333333333, 0.7222222222222222, 'Price <= 17.49\ngini = 0.444\nsamples = 1013\nvalue = [676, 337]\nclass = is_Not_multiplayer'),
#  Text(0.55, 0.6111111111111112, 'Price <= 15.495\ngini = 0.432\nsamples = 507\nvalue = [347, 160]\nclass = is_Not_multiplayer'),
#  Text(0.5166666666666667, 0.5, 'Price <= 14.995\ngini = 0.438\nsamples = 476\nvalue = [322, 154]\nclass = is_Not_multiplayer'),
#  Text(0.5, 0.3888888888888889, 'gini = 0.438\nsamples = 473\nvalue = [320, 153]\nclass = is_Not_multiplayer'),
#  Text(0.5333333333333333, 0.3888888888888889, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = is_Not_multiplayer'),
#  Text(0.5833333333333334, 0.5, 'Price <= 16.49\ngini = 0.312\nsamples = 31\nvalue = [25, 6]\nclass = is_Not_multiplayer'),
#  Text(0.5666666666666667, 0.3888888888888889, 'gini = 0.308\nsamples = 21\nvalue = [17, 4]\nclass = is_Not_multiplayer'),
#  Text(0.6, 0.3888888888888889, 'gini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = is_Not_multiplayer'),
#  Text(0.6666666666666666, 0.6111111111111112, 'Price <= 20.49\ngini = 0.455\nsamples = 506\nvalue = [329, 177]\nclass = is_Not_multiplayer'),
#  Text(0.65, 0.5, 'Price <= 19.49\ngini = 0.456\nsamples = 504\nvalue = [327, 177]\nclass = is_Not_multiplayer'),
#  Text(0.6333333333333333, 0.3888888888888889, 'Price <= 18.49\ngini = 0.493\nsamples = 25\nvalue = [14, 11]\nclass = is_Not_multiplayer'),
#  Text(0.6166666666666667, 0.2777777777777778, 'gini = 0.475\nsamples = 18\nvalue = [11, 7]\nclass = is_Not_multiplayer'),
#  Text(0.65, 0.2777777777777778, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = is_multiplayer'),
#  Text(0.6666666666666666, 0.3888888888888889, 'gini = 0.453\nsamples = 479\nvalue = [313, 166]\nclass = is_Not_multiplayer'),
#  Text(0.6833333333333333, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = is_Not_multiplayer'),
#  Text(0.825, 0.7222222222222222, 'Price <= 35.99\ngini = 0.499\nsamples = 342\nvalue = [162, 180]\nclass = is_multiplayer'),
#  Text(0.7333333333333333, 0.6111111111111112, 'Price <= 23.16\ngini = 0.499\nsamples = 201\nvalue = [105, 96]\nclass = is_Not_multiplayer'),
#  Text(0.7166666666666667, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.75, 0.5, 'Price <= 24.49\ngini = 0.499\nsamples = 200\nvalue = [105, 95]\nclass = is_Not_multiplayer'),
#  Text(0.7333333333333333, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.7666666666666667, 0.3888888888888889, 'Price <= 32.49\ngini = 0.499\nsamples = 199\nvalue = [104, 95]\nclass = is_Not_multiplayer'),
#  Text(0.7333333333333333, 0.2777777777777778, 'Price <= 30.99\ngini = 0.499\nsamples = 182\nvalue = [94, 88]\nclass = is_Not_multiplayer'),
#  Text(0.7166666666666667, 0.16666666666666666, 'Price <= 27.49\ngini = 0.499\nsamples = 181\nvalue = [94, 87]\nclass = is_Not_multiplayer'),
#  Text(0.7, 0.05555555555555555, 'gini = 0.5\nsamples = 77\nvalue = [39, 38]\nclass = is_Not_multiplayer'),
#  Text(0.7333333333333333, 0.05555555555555555, 'gini = 0.498\nsamples = 104\nvalue = [55, 49]\nclass = is_Not_multiplayer'),
#  Text(0.75, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.8, 0.2777777777777778, 'Price <= 33.99\ngini = 0.484\nsamples = 17\nvalue = [10, 7]\nclass = is_Not_multiplayer'),
#  Text(0.7833333333333333, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.8166666666666667, 0.16666666666666666, 'gini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = is_Not_multiplayer'),
#  Text(0.9166666666666666, 0.6111111111111112, 'Price <= 59.97\ngini = 0.482\nsamples = 141\nvalue = [57, 84]\nclass = is_multiplayer'),
#  Text(0.8666666666666667, 0.5, 'Price <= 38.49\ngini = 0.456\nsamples = 105\nvalue = [37, 68]\nclass = is_multiplayer'),
#  Text(0.85, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.8833333333333333, 0.3888888888888889, 'Price <= 54.97\ngini = 0.458\nsamples = 104\nvalue = [37, 67]\nclass = is_multiplayer'),
#  Text(0.8666666666666667, 0.2777777777777778, 'Price <= 47.49\ngini = 0.46\nsamples = 103\nvalue = [37, 66]\nclass = is_multiplayer'),
#  Text(0.85, 0.16666666666666666, 'Price <= 42.49\ngini = 0.447\nsamples = 77\nvalue = [26, 51]\nclass = is_multiplayer'),
#  Text(0.8333333333333334, 0.05555555555555555, 'gini = 0.459\nsamples = 70\nvalue = [25, 45]\nclass = is_multiplayer'),
#  Text(0.8666666666666667, 0.05555555555555555, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = is_multiplayer'),
#  Text(0.8833333333333333, 0.16666666666666666, 'gini = 0.488\nsamples = 26\nvalue = [11, 15]\nclass = is_multiplayer'),
#  Text(0.9, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.9666666666666667, 0.5, 'Price <= 94.99\ngini = 0.494\nsamples = 36\nvalue = [20, 16]\nclass = is_Not_multiplayer'),
#  Text(0.95, 0.3888888888888889, 'Price <= 84.99\ngini = 0.48\nsamples = 30\nvalue = [18, 12]\nclass = is_Not_multiplayer'),
#  Text(0.9333333333333333, 0.2777777777777778, 'Price <= 62.49\ngini = 0.485\nsamples = 29\nvalue = [17, 12]\nclass = is_Not_multiplayer'),
#  Text(0.9166666666666666, 0.16666666666666666, 'gini = 0.48\nsamples = 25\nvalue = [15, 10]\nclass = is_Not_multiplayer'),
#  Text(0.95, 0.16666666666666666, 'Price <= 72.49\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = is_Not_multiplayer'),
#  Text(0.9333333333333333, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = is_multiplayer'),
#  Text(0.9666666666666667, 0.05555555555555555, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = is_Not_multiplayer'),
#  Text(0.9666666666666667, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = is_Not_multiplayer'),
#  Text(0.9833333333333333, 0.3888888888888889, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = is_multiplayer')]

# %%
# Out:
#       gamesid                    appName appType  price         release_Date  \
# 0          10             Counter-Strike    game   9.99  2000-11-01 00:00:00
# 1          20      Team Fortress Classic    game   4.99  1999-04-01 00:00:00
# 2          30              Day of Defeat    game   4.99  2003-05-01 00:00:00
# 3          40         Deathmatch Classic    game   4.99  2001-06-01 00:00:00
# 4          50  Half-Life: Opposing Force    game   4.99  1999-11-01 00:00:00
# ...       ...                        ...     ...    ...                  ...
# 7512   463180         Super Blue Fighter    game   0.99  2016-05-05 00:00:00
# 7525   463920    Initia: Elemental Arena    game  19.99  2016-04-29 00:00:00
# 7550   466910          Worm.is: The Game    game   0.00  2016-05-04 00:00:00
# 7554   467320                God of Word    game   0.00  1970-01-01 00:00:00
# 7557   467910                      EP?CH    game   0.00  2016-05-03 00:00:00
#
#       rating  requiredAge  is_Multiplayer  steam_appid  average_forever  \
# 0         88            0               1           10            17612
# 1         -1            0               1           20              277
# 2         79            0               1           30              187
# 3         -1            0               1           40              258
# 4         -1            0               1           50              624
# ...      ...          ...             ...          ...              ...
# 7512      -1            0               1       463180              206
# 7525      -1            0               1       463920                0
# 7550      -1            0               1       466910               68
# 7554      -1            0               1       467320                0
# 7557      -1            0               1       467910                0
#
#                         owners achievement  ownersNumerical
# 0     10,000,000 .. 20,000,000         Yes          1500000
# 1      5,000,000 .. 10,000,000         Yes          7500000
# 2      5,000,000 .. 10,000,000         Yes          7500000
# 3      5,000,000 .. 10,000,000         Yes          7500000
# 4      5,000,000 .. 10,000,000         Yes          7500000
# ...                        ...         ...              ...
# 7512        100,000 .. 200,000          No           150000
# 7525               0 .. 20,000          No            10000
# 7550    1,000,000 .. 2,000,000          No           150000
# 7554          20,000 .. 50,000          No            35000
# 7557               0 .. 20,000          No            10000
#
# [1810 rows x 13 columns]
