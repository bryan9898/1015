# %%
#import libraries
import numpy as np
import pandas as pd
import datetime
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Data

# %%
steam_data = pd.read_csv('AllSteamData.csv')
steam_data.head()
# Out:
#              Name         Month  Avg. Players     Gain   % Gain  Peak Players
# 0  Counter-Strike  Last 30 Days       8488.74     27.6    0.33%         15065
# 1  Counter-Strike        Sep-21       8461.12  -390.07   -4.41%         14559
# 2  Counter-Strike        Aug-21       8851.19  -286.57   -3.14%         14064
# 3  Counter-Strike        Jul-21       9137.76  -359.69   -3.79%         14972
# 4  Counter-Strike        Jun-21       9497.45  -1243.5  -11.58%         16391

# %%
steam_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878175 entries, 0 to 878174
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Name          878175 non-null  object
#  1   Month         878175 non-null  object
#  2   Avg. Players  878175 non-null  float64
#  3   Gain          867341 non-null  object
#  4   % Gain        867341 non-null  object
#  5   Peak Players  878175 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 40.2+ MB

# %% [markdown]
# # Cleaning Dataset

# %%
steam_data_clean=steam_data.copy()
steam_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878175 entries, 0 to 878174
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Name          878175 non-null  object
#  1   Month         878175 non-null  object
#  2   Avg. Players  878175 non-null  float64
#  3   Gain          867341 non-null  object
#  4   % Gain        867341 non-null  object
#  5   Peak Players  878175 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 40.2+ MB

# %%
#Drop Duplicates
steam_data_clean.drop_duplicates()

#cleaning the % Gain column
steam_data_clean['% Gain'] = steam_data_clean['% Gain'].str.replace("%","")

#filling the NULL values in Gain and % Gain to 0
steam_data_clean.Gain[steam_data_clean.Gain == '-'] = 0
steam_data_clean['% Gain'][steam_data_clean['% Gain'] == 'NaN'] = 0
steam_data_clean['% Gain'][steam_data_clean['% Gain'] == '-'] = 0
steam_data_clean.fillna(value = 0, inplace = True)

#cleaning the Month column
steam_data_clean['Month'] = steam_data_clean['Month'].str.replace("Last 30 Days","Oct-21")
steam_data_clean['Month'] = pd.to_datetime(steam_data_clean['Month'], format='%b-%y')
# Out:
# C:\Users\choww\AppData\Local\Temp/ipykernel_22268/3073407251.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_data_clean.Gain[steam_data_clean.Gain == '-'] = 0
# C:\Users\choww\AppData\Local\Temp/ipykernel_22268/3073407251.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_data_clean['% Gain'][steam_data_clean['% Gain'] == 'NaN'] = 0
# C:\Users\choww\AppData\Local\Temp/ipykernel_22268/3073407251.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_data_clean['% Gain'][steam_data_clean['% Gain'] == '-'] = 0

# %%
steam_data_clean.sample(20)
# Out:
#                                           Name      Month  Avg. Players  \
# 471980                               Bladestar 2017-02-01          0.15
# 460105                                Recourse 2019-08-01          0.08
# 493447                  Asteroid Bounty Hunter 2016-08-01          4.65
# 704054      War Planet Online: Global Conquest 2021-05-01        330.39
# 655011  Idle Champions of the Forgotten Realms 2018-02-01       3462.64
# 305046               The House in Fata Morgana 2020-09-01         12.06
# 434085           Attrition: Nuclear Domination 2018-06-01          0.94
# 207949                 Q.U.B.E: Director's Cut 2016-10-01          3.59
# 445998               FlatOut 4: Total Insanity 2019-11-01         10.77
# 23158                Hitman 2: Silent Assassin 2020-07-01         21.12
# 513632                       Predynastic Egypt 2018-08-01          8.19
# 217299                               Tropico 5 2020-07-01        348.48
# 675906                    Dead Space: Downfall 2017-12-01          1.06
# 657669                        Clicker Heroes 2 2018-07-01       5440.46
# 11936                          AstroPop Deluxe 2015-08-01          1.21
# 802321                                 Zengeon 2019-10-01         10.83
# 46319        Tom Clancy's Rainbow Six: Vegas 2 2021-06-01         27.57
# 40794                         Max Payne 2 (RU) 2016-04-01          1.76
# 850512                             Gnomes & Co 2021-10-01          0.00
# 596554            Warhammer 40,000: Space Wolf 2017-04-01         13.09
#
#            Gain  % Gain  Peak Players
# 471980     0.07   96.10             3
# 460105     0.01   15.36             1
# 493447    -1.92  -29.28            17
# 704054     3.25    0.99           644
# 655011  -131.56   -3.66          4281
# 305046    -0.48   -3.82            36
# 434085    -0.23  -19.89             7
# 207949    -0.31   -8.02            11
# 445998     5.63  109.44            39
# 23158      3.43   19.42            48
# 513632    -4.41  -35.00            20
# 217299     92.8   36.30           821
# 675906    -3.21  -75.27             5
# 657669        0       0          9570
# 11936      0.15   14.36             5
# 802321     1.12   11.47            55
# 46319      1.41    5.39            72
# 40794      0.08    4.59             9
# 850512        0       0             0
# 596554   -14.41  -52.40            47

# %%
steam_data_clean.describe()
# Out:
#        Avg. Players  Peak Players
# count  8.781750e+05  8.781750e+05
# mean   3.298315e+02  6.828038e+02
# std    8.601823e+03  1.623968e+04
# min    0.000000e+00  0.000000e+00
# 25%    3.900000e-01  3.000000e+00
# 50%    2.520000e+00  1.100000e+01
# 75%    1.752000e+01  5.700000e+01
# max    1.584887e+06  3.236027e+06

# %% [markdown]
# # Exploring the Dataset

# %%
#Top 20 Games by Avg Players for all time
Top_20 = steam_data_clean.sort_values('Avg. Players', ascending=False)

#Only keep the Highest occurence
Top_20 = Top_20.drop_duplicates(subset=['Name'], keep='first').head(20)
Top_20
# Out:
#                                     Name      Month  Avg. Players       Gain  \
# 618079               PUBG: BATTLEGROUNDS 2018-01-01    1584886.77  148728.26
# 3364    Counter-Strike: Global Offensive 2020-04-01     857604.22  186570.94
# 3078                              Dota 2 2016-02-01     709178.26   97003.48
# 817899                         New World 2021-10-01     461109.04          0
# 824204                    Cyberpunk 2077 2020-12-01     332395.65          0
# 413277                         Fallout 4 2015-11-01     226297.83          0
# 771929                           Valheim 2021-02-01     210302.24          0
# 258827                Grand Theft Auto V 2015-04-01     192714.01          0
# 621248             Monster Hunter: World 2018-08-01     188291.24          0
# 787669                          Among Us 2020-10-01     176453.91   25073.63
# 839176                      Apex Legends 2021-08-01     169528.17    38377.1
# 822946                         Destiny 2 2019-10-01     165307.82          0
# 228817                              Rust 2021-01-01     142117.25    80945.6
# 135524                          Terraria 2020-05-01     129808.62   78493.53
# 825632      Fall Guys: Ultimate Knockout 2020-08-01     124479.35          0
# 387009    Tom Clancy's Rainbow Six Siege 2020-03-01     119877.88   22210.54
# 243343      Mount & Blade II: Bannerlord 2020-04-01     113492.99  113492.74
# 2460                     Team Fortress 2 2021-06-01     106222.95   16690.73
# 730690         Total War: THREE KINGDOMS 2019-05-01     102719.07  102719.01
# 366086             ARK: Survival Evolved 2020-03-01      87738.70   34344.52
#
#               % Gain  Peak Players
# 618079         10.36       3236027
# 3364           27.80       1305714
# 3078           15.85       1248394
# 817899             0        913027
# 824204             0        830387
# 413277             0        471955
# 771929             0        498478
# 258827             0        360761
# 621248             0        329333
# 787669         16.56        372646
# 839176         29.26        330476
# 822946             0        292314
# 228817        132.33        244394
# 135524        152.96        486918
# 825632             0        172026
# 387009         22.74        198567
# 243343   45090359.40        248034
# 2460           18.64        150037
# 730690  162296033.94        191816
# 366086         64.32        157355

# %%
#Exploring data range for Avg. Players
avg = pd.DataFrame(Top_20[["Avg. Players", "Name"]])

#Using Bar graph
f = plt.figure(figsize=(16, 8))
sb.barplot(x="Avg. Players", y="Name", data=avg)
# Out:
# <AxesSubplot:xlabel='Avg. Players', ylabel='Name'>

# %% [markdown]
# It can be seen that there is a huge disparity between the number of average players for the top 20 games of all time.
